# %%
##classification

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import accuracy_score,mean_squared_error,r2_score

# %%
df=pd.read_csv("C:/Users/vinod/Downloads/clean_social.csv")
df
# Out:
#     id  gender  age education profession workDuration  \
# 0    1    male   35    master    manager      8 years
# 1    2    male   27    degree    officer      5 years
# 2    3  female   24    degree    officer      4 years
# 3    4    male   35    master    manager      8 years
# 4    5    male   27    degree    officer      5 years
# 5    6  female   28    degree    officer      4 years
# 6    7    male   35    master    manager      8 years
# 7    8    male   43    degree   lectural      5 years
# 8    9  female   21    degree    officer      4 years
# 9   10    male   35    master    manager      8 years
# 10  11    male   27    degree    officer      5 years
# 11  12  female   32    degree    officer      4 years
# 12  13    male   35    master    manager      8 years
# 13  14    male   27    degree    officer      5 years
# 14  15  female   21    degree    officer      4 years
# 15  16    male   35    master    manager      8 years
# ...

# %%
data=df.drop(['id','gender','education','productivity'],axis=1)
data
# Out:
#     age profession workDuration  \
# 0    35    manager      8 years
# 1    27    officer      5 years
# 2    24    officer      4 years
# 3    35    manager      8 years
# 4    27    officer      5 years
# 5    28    officer      4 years
# 6    35    manager      8 years
# 7    43   lectural      5 years
# 8    21    officer      4 years
# 9    35    manager      8 years
# 10   27    officer      5 years
# 11   32    officer      4 years
# 12   35    manager      8 years
# 13   27    officer      5 years
# 14   21    officer      4 years
# 15   35    manager      8 years
# 16   27    officer      7 years
# 17   21    officer      4 years
# 18   35    manager      8 years
# 19   27    officer      5 years
# 20   21    officer      4 years
# 21   35    manager      8 years
# 22   27    officer      5 years
# 23   45    officer      4 years
# 24   21    officer      4 years
# 25   47    officer      9 years
# 26   21    officer      4 years
# 27   29    officer      4 years
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["typeSocial"] = le.fit_transform(data["typeSocial"])
data
# Out:
#     age profession workDuration  typeSocial  useSocial  socialDuration
# 0    35    manager      8 years           1      often               6
# 1    27    officer      5 years           3   regulary               7
# 2    24    officer      4 years           0  everytime               4
# 3    35    manager      8 years           1      often               8
# 4    27    officer      5 years           3   regulary               6
# 5    28    officer      4 years           0  everytime               2
# 6    35    manager      8 years           1      often               4
# 7    43   lectural      5 years           2   regulary               3
# 8    21    officer      4 years           0  everytime               8
# 9    35    manager      8 years           1      often               5
# 10   27    officer      5 years           3   regulary               6
# 11   32    officer      4 years           0  everytime               4
# ...

# %%
data["profession"] = le.fit_transform(data["profession"])
data
# Out:
#     age  profession workDuration  typeSocial  useSocial  socialDuration
# 0    35           1      8 years           1      often               6
# 1    27           2      5 years           3   regulary               7
# 2    24           2      4 years           0  everytime               4
# 3    35           1      8 years           1      often               8
# 4    27           2      5 years           3   regulary               6
# 5    28           2      4 years           0  everytime               2
# 6    35           1      8 years           1      often               4
# 7    43           0      5 years           2   regulary               3
# 8    21           2      4 years           0  everytime               8
# 9    35           1      8 years           1      often               5
# 10   27           2      5 years           3   regulary               6
# 11   32           2      4 years           0  everytime               4
# ...

# %%
data["useSocial"] = le.fit_transform(data["useSocial"])
data
# Out:
#     age  profession workDuration  typeSocial  useSocial  socialDuration
# 0    35           1      8 years           1          1               6
# 1    27           2      5 years           3          2               7
# 2    24           2      4 years           0          0               4
# 3    35           1      8 years           1          1               8
# 4    27           2      5 years           3          2               6
# 5    28           2      4 years           0          0               2
# 6    35           1      8 years           1          1               4
# 7    43           0      5 years           2          2               3
# 8    21           2      4 years           0          0               8
# 9    35           1      8 years           1          1               5
# 10   27           2      5 years           3          2               6
# 11   32           2      4 years           0          0               4
# ...

# %%
x=data.drop(['workDuration','typeSocial','socialDuration'],axis=1)
x
# Out:
#     age  profession  useSocial
# 0    35           1          1
# 1    27           2          2
# 2    24           2          0
# 3    35           1          1
# 4    27           2          2
# 5    28           2          0
# 6    35           1          1
# 7    43           0          2
# 8    21           2          0
# 9    35           1          1
# 10   27           2          2
# 11   32           2          0
# 12   35           1          1
# 13   27           2          2
# 14   21           2          0
# 15   35           1          1
# 16   27           2          2
# 17   21           2          0
# 18   35           1          1
# 19   27           2          2
# 20   21           2          0
# 21   35           1          1
# 22   27           2          2
# 23   45           2          0
# 24   21           2          0
# 25   47           2          2
# 26   21           2          0
# 27   29           2          0
# 28   36           1          2
# ...

# %%
y=data[['socialDuration']]
y
# Out:
#     socialDuration
# 0                6
# 1                7
# 2                4
# 3                8
# 4                6
# 5                2
# 6                4
# 7                3
# 8                8
# 9                5
# 10               6
# 11               4
# 12               8
# 13               6
# 14               2
# 15               4
# 16               3
# 17               8
# 18               5
# 19               6
# 20               4
# 21               8
# 22               6
# 23               2
# 24               4
# 25               3
# 26               8
# 27               5
# 28               6
# 29               4
# 30               6
# 31               2
# 32               4
# 33               3
# 34               8
# 35               5
# 36               6
# 37               4
# 38               8

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(xtrain, ytrain)
# Out:
# C:\Users\vinod\AppData\Local\Temp\ipykernel_4276\1922436551.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(xtrain, ytrain)
# RandomForestRegressor(random_state=42)

# %%
ypred = model.predict(xtest)
ypred
# Out:
# array([4.85481746, 5.9560119 , 5.52986905, 5.52986905, 4.43290729,
#        4.85481746, 5.92630123, 4.029     , 4.85481746, 5.92630123])

# %%
mse = mean_squared_error(ytest, ypred)

# %%
mse
# Out:
# 2.53271085385627

# %%
mse = mean_squared_error(ytest, ypred)

print(f'Mean Squared Error: {mse:.2f}')
# Out:
# Mean Squared Error: 2.53
